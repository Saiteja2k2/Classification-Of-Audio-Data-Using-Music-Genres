# %%
from tensorflow.keras.preprocessing import image
from tensorflow.python.keras.models import load_model
from werkzeug.utils import secure_filename
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization
import numpy as np
import pandas as pd
import os
import librosa, warnings
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import load_model
 
from scipy.io.wavfile import write
import time
from collections import Counter

### Flask imports
import requests
from flask import Flask, render_template, session, request, redirect, flash, Response, url_for
app = Flask(__name__)
 
 

final = pd.read_pickle("extracted_df.pkl")
y = np.array(final["label"].tolist())
le = LabelEncoder()
le.fit_transform(y)
model = tf.keras.models.load_model('Model1.h5', compile=False)


def extract_feature(audio_path):
    audio_data, sample_rate = librosa.load(audio_path, res_type="kaiser_fast")
    feature = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
    feature_scaled = np.mean(feature.T, axis=0)
    return np.array([feature_scaled])


def ANN_print_prediction(audio_path):
    prediction_feature = extract_feature(audio_path)
    predicted_vector = np.argmax(model.predict(prediction_feature), axis=-1)
    predicted_class = le.inverse_transform(predicted_vector)
    return predicted_class[0]

@app.route("/")
@app.route("/first")
def first():
	return render_template('first.html')
    
@app.route("/login")
def login():
	return render_template('login.html')  
    
@app.route("/index", methods=['GET'])
def index():
	return render_template("index.html")


@app.route("/submit", methods = ['GET', 'POST'])
def get_output():
	if request.method == 'POST':
		audio_path = request.files['wavfile']

		img_path = "static/tests/" + audio_path.filename	
		audio_path.save(img_path)
	 
		predict_result =  ANN_print_prediction(img_path)

	return render_template("prediction.html", prediction = predict_result, audio_path= img_path)

 
@app.route("/chart")
def chart():
	return render_template('chart.html')     
 
if __name__ =='__main__':
	app.run(host = '0.0.0.0',port = 8080)
# Out:
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\dell\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# WARNING:tensorflow:From C:\Users\dell\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://192.168.0.109:8080
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Apr/2024 20:49:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:49:55] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:55] "GET /static/css/templatemo-festava-live.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:55] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/video/pexels-2022395.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:49:56] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:49:57] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/css/templatemo-festava-lives.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/video/music1.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:50:12] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:50:13] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/css/templatemo-festava-lives.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/video/music4.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /images/background1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /images/background2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:09] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/css/templatemo-festava-lives.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /images/background2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:47] "GET /images/background1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:48] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:52:48] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 [==============================] - 3s 3s/step
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/css/templatemo-festava-lives.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/tests/pop.000023.wav HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /static/video/music5.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:53:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:53:31] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:53:31] "GET /static/tests/pop.000023.wav HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:54:22] "GET /static/video/music5.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:54:22] "GET /static/video/music5.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/css/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/result.png HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/css/templatemo-festava-lives.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/results.png HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/js/jquery.sticky.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/js/click-scroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/js/custom.js HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/images/nainoa-shizuru-NcdG9mK3PBY-unsplash.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /static/video/music7.mp4 HTTP/1.1" 206 -
# 127.0.0.1 - - [30/Apr/2024 20:54:25] "GET /favicon.ico HTTP/1.1" 404 -
